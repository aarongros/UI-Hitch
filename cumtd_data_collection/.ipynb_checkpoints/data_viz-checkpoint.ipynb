# %%
# install.packages("RSQLite")
# install.packages("Hmisc")
library("DBI")
library(Hmisc)
date <- "2018-11-14"

# %%
conn <- dbConnect(RSQLite::SQLite(), "stop_times.db")
res <- dbSendQuery(conn, paste0("SELECT arrival_time,\"", date, "\" FROM stop_times WHERE \"", date, "\" IS NOT NULL"))
all_vals <- dbFetch(res)
vals <- all_vals[[date]]

# %% [markdown]
# ### Some summary statistics

# %%
Hmisc::describe(vals)
summary(vals)
# Out:
# vals
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#    42201        0      855    0.846    71.52    126.5        0        0
#      .25      .50      .75      .90      .95
#        0        0      104      263      353
#
# -15200 (2, 0.000), -14400 (2, 0.000), -4200 (1, 0.000), -2400 (5, 0.000), -1600
# (2, 0.000), -1400 (1, 0.000), -1200 (4, 0.000), -1000 (16, 0.000), -800 (11,
# 0.000), -600 (37, 0.001), -400 (27, 0.001), -200 (337, 0.008), 0 (30608,
# 0.725), 200 (8164, 0.193), 400 (2352, 0.056), 600 (469, 0.011), 800 (133,
# 0.003), 1000 (27, 0.001), 1400 (1, 0.000), 1800 (2, 0.000)
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -15202.00      0.00      0.00     71.52    104.00   1801.00

# %%
print(paste0("average delay of buses: ", round(mean(vals), 4), " seconds"))
print(paste0("buses that arrived exactly on time: ", round(mean(vals == 0), 3)*100, "%"))
print(paste0("buses that weren't early but less than a minute late: ", round(mean(vals >= 0 & vals < 60), 3)*100, "%"))
print(paste0("buses that were within 30 seconds of their scheduled time: ", round(mean(abs(vals) < 30), 3)*100, "%"))
print(paste0("buses that were more than 5 minutes late: ", round(mean(vals > 300), 3)*100, "%"))
print(paste0("buses that were more than 5 minutes early: ", round(mean(vals < -300), 3)*100, "%"))
# Out:
# [1] "average delay of buses: 71.518 seconds"
# [1] "buses that arrived exactly on time: 53.6%"
# [1] "buses that weren't early but less than a minute late: 59.6%"
# [1] "buses that were within 30 seconds of their scheduled time: 58.5%"
# [1] "buses that were more than 5 minutes late: 7.1%"
# [1] "buses that were more than 5 minutes early: 0.3%"

# %%
histinfo <- hist(vals, breaks=1000, freq=FALSE, xlab="Bus Delay (sec)", main=paste("Histogram of Bus Delays on", date))
# Out:
# Plot with title “Histogram of Bus Delays on 2018-11-14”

# %%
head(sorted_highest_peaks <- histinfo$density[order(histinfo$density, decreasing = TRUE)])
# Out:
# [1] 0.027377313 0.003459634 0.001898059 0.001674131 0.001387408 0.001187176

# %%
hist(vals, breaks=1000, xlim=c(mean(vals)-2*sd(vals), mean(vals)+2*sd(vals)), ylim=c(0,sorted_highest_peaks[2]), freq=FALSE, xlab="Bus Delay (sec)", main=paste("[Zoomed +-2SD] Histogram of Bus Delays on", date))
# Out:
# Plot with title “[Zoomed +-2SD] Histogram of Bus Delays on 2018-11-14”

# %%
hist(vals, breaks=1000, ylim=c(0,sorted_highest_peaks[3]), freq=FALSE, xlab="Bus Delay (sec)", main=paste("[Zoomed in Density] Histogram of Bus Delays on", date))
# Out:
# Plot with title “[Zoomed in Density] Histogram of Bus Delays on 2018-11-14”

# %%
hist(vals, breaks=1000, ylim=c(0,sorted_highest_peaks[3]), freq=FALSE, xlab="Bus Delay (sec)", main="Histogram of Bus Delays + Normal Curve Superimposed")
curve(dnorm(x, mean(vals), sd(vals)), add=TRUE, col='RED')
# Out:
# Plot with title “Histogram of Bus Delays + Normal Curve Superimposed”

# %%
arrTimes <- as.list(all_vals[['arrival_time']])
arrTimeDates <- sapply(arrTimes, function (time) {paste(date, time)})
arrPOSIX <- as.POSIXct(arrTimeDates, format="%Y-%m-%d %H:%M:%S", origin="1960-01-01")
cols <- rep(1, length(vals))
cols[vals == 0] <- 2
plot(vals ~ arrPOSIX, xlab="Time", ylab="Delay (sec)", main=paste("Delay of buses over Time of Day on", date), las=1, pch=20, col=cols)
axis.POSIXct(1, x=arrPOSIX)

# add vertical lines to show beginning of hour, in case variation was higher at the beginnning of the hour
lines <- as.POSIXct(sapply(seq(0, 24, 1), function (time) {paste(date, time)}), format="%Y-%m-%d %H")
abline(v=lines)

# linear model
fit <- lm(vals ~ arrPOSIX)
abline(fit, col="BLUE", lwd=3)

# technically shouldn't be correlated? need more data to prove (could be sample size causing less variability)
summary(fit)
# Out:
# Call:
# lm(formula = vals ~ arrPOSIX)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15269.0    -73.6    -64.3     35.5   1736.2
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.880e+05  9.816e+04   4.971 6.67e-07 ***
# arrPOSIX    -3.164e-04  6.365e-05  -4.971 6.70e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 202.6 on 42199 degrees of freedom
# Multiple R-squared:  0.0005852,	Adjusted R-squared:  0.0005615
# F-statistic: 24.71 on 1 and 42199 DF,  p-value: 6.698e-07
# Plot with title “Delay of buses over Time of Day on 2018-11-14”

# %%
res <- dbSendQuery(conn, paste0("SELECT DISTINCT route_id FROM stop_times"))
all_routes <- dbFetch(res)
length(all_routes[['route_id']])
# Out:
# Warning message:
# “Closing open result set, pending rows”
# [1] 101

# %%
res <- dbSendQuery(conn, "SELECT route_id, \"2018-11-12\", \"2018-11-13\", \"2018-11-14\" FROM stop_times ORDER BY route_id")
head(all_departures <- dbFetch(res))
# Out:
# Warning message:
# “Closing open result set, pending rows”
#   route_id     2018-11-12 2018-11-13 2018-11-14
# 1 1 YELLOW ALT NA         NA         NA
# 2 1 YELLOW ALT NA         NA         NA
# 3 1 YELLOW ALT NA         NA         NA
# 4 1 YELLOW ALT NA         NA         NA
# 5 1 YELLOW ALT NA         NA         NA
# 6 1 YELLOW ALT NA         NA         NA

# %%
filter <- all_departures[['2018-11-14']] < 500 & all_departures[['2018-11-14']] > -500
x <- all_departures[['2018-11-14']][filter]
png(filename="all_routes.png", width=10, height=10, units="in", res=600)
histogram(~x | all_departures[['route_id']][filter],
          xlim=c(-500,500),
          ylim=c(0,8),
          breaks=seq(-500,500,5),
#           par.strip.text=list(cex=0.5),
          layout=c(8,13))
dev.off()
# Out:
# pdf
#   2
